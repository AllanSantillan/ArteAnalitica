# %%
#lectura del archivo csv
import pandas as pd
data=pd.read_csv("covid19_tweets.csv")
#data.head(20)

# %%
#Convertimos los datos
dt=pd.DataFrame(data)
dt
# Out:
#                       user_name         user_location  \
# 0                        ᏉᎥ☻լꂅϮ            astroworld
# 1                 Tom Basile 🇺🇸          New York, NY
# 2               Time4fisticuffs      Pewee Valley, KY
# 3                   ethel mertz  Stuck in the Middle
# 4                      DIPR-J&K     Jammu and Kashmir
# ...                         ...                   ...
# 74431             Laura Wolfrom         Lexington, KY
# 74432  Professor Tonya M. Evans         😷 #stayathome
# 74433        People's Daily app           北京, 中华人民共和国
# 74434                     M0ser                   NaN
# 74435    Your Friend & Sabre ⚔️           Chicago, IL
#
#                                         user_description         user_created  \
# 0      wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1      Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2      #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# ...

# %%
#Podemos obtener las columnas que van a definr a mis datos
dt.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')

# %%
#Ahora se obtendra el tipo de dato por cada columan 
dt.dtypes
# Out:
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object

# %%
#Con el siguiente comando vamos a obtener los datos numericos 
dt.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    7.443600e+04   74436.000000     7.443600e+04
# mean     1.059513e+05    2154.721170     1.529747e+04
# std      8.222900e+05    9365.587474     4.668971e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      1.660000e+02     153.000000     2.200000e+02
# 50%      9.600000e+02     552.000000     1.927000e+03
# 75%      5.148000e+03    1780.250000     1.014800e+04
# max      1.389284e+07  497363.000000     2.047197e+06

# %%
dt['user_verified']. describe()
# Out:
# count     74436
# unique        2
# top       False
# freq      65082
# Name: user_verified, dtype: object

# %%
#plot
import matplotlib.pyplot as plt
colA=dt['user_followers']
colB=dt['user_friends']
colC=dt['user_favourites']
#colD=dt["user_created"]
myD=[colA,colB,colC]
f=plt.figure(figsize=(10,8))
ax=f.add_axes([0,0,1,1])
bp=ax.boxplot(myD)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9bb798de8609> in <module>
#       1 #plot
#       2 import matplotlib.pyplot as plt
# ----> 3 colA=dt['user_followers']
#       4 colB=dt['user_friends']
#       5 colC=dt['user_favourites']
#
# NameError: name 'dt' is not defined

# %%
#Ahora haremos el histograma 
n_bins=20
colors=["green", "blue", "red"]
plt.hist(myD,n_bins,density = True,
         histtype="bar",
         color = colors,
         label = colors)
plt.legend(prop={"size":12})
plt.title("Histograma de archivo Covid_Tweets\n\n",
         fontweight="bold")
plt.show()

# %%
df =data.corr(method="pearson")
tose = [df["XLarge Bags"],df["Large Bags"], df["Small Bags"],df["Total Bags"]]
sns.heatmap(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fc61f5c2824c> in <module>
# ----> 1 df =data.corr(method="pearson")
#       2 tose = [df["XLarge Bags"],df["Large Bags"], df["Small Bags"],df["Total Bags"]]
#       3 sns.heatmap(df)
#       4 plt.show()
#       5
#
# NameError: name 'data' is not defined
